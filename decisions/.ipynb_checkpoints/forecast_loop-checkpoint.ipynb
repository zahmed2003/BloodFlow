# %%
import numpy as np
import matplotlib.pyplot as plt
import cvxpy as cp
import networkx as nx
import pandas as pd
from sklearn.linear_model import LinearRegression
import xgboost as xgb
from tqdm import tqdm 
import seaborn as sns
import warnings
import arviz as az
warnings.filterwarnings('ignore', category = UserWarning)

# %%
# helper method for getting next step, returning the action to take, the supply in the next step, and the loan
def get_next_step(W,b_max,Q_max,B_init,forecast,gamma=0.999,alpha=1.0):

    S = forecast[:,:,0]
    D = forecast[:,:,1]
    N = len(S)
    F = len(S[0])
    G = np.diag(gamma**np.arange(F))
    
    B = cp.Variable([N,F+1])
    Q = cp.Variable([N,N,F])
    M = cp.Variable([N,F])
    
    obj_func = cp.sum([cp.norm(G@m_k,1) for m_k in M]) + alpha*cp.sum([cp.norm(cp.multiply(W,Q[:,:,t]),2) for t in range(F)])
    obj = cp.Minimize(obj_func)
    
    constr =  []
    
    # IC
    constr += [B[:,0] == B_init]
    # constr += [M>=0]
    
    
    # max storage
    for t in range(F+1):
        constr +=[B[:,t]<=b_max]
        
    # dynamics    
    for t in range(F):
        for k in range(N):
            constr += [B[k,t+1] == B[k,t] + S[k,t] - D[k,t] + cp.sum(Q[k,:,t])+ M[k,t]]
    
    # storage constraints
    for t in range(F+1):
        constr +=[0<= B[:,t]]
    
    
    ##shipments
    for k in range(N):
        for l in range(N):
            constr +=[Q[k,l] == -Q[l,k]]
    
    for k in range(N):
        for t in range(F):
            constr += [cp.sum(Q[:,k,t]) <= B[k,t]]
    
    constr += [cp.norm(Q,'inf') <= Q_max]
    prob = cp.Problem(obj,constr)
    prob.solve()
    
    Q_opt = Q.value
    B_opt = B[:,1:].value
    M_opt = M.value

    return Q_opt[:,:,0],M_opt[:,0]

# %%
def forecast_loop(data,B_init,test_length,W,b_max,Q_max,forecaster,model,f=7,h=7,gamma=0.999,alpha=1.0):
    data_real = data[:,-test_length:,:] # N x test_length x 2
    offset = len(data[0]) - test_length

    Q_mat = []
    B_mat = [B_init]
    M_mat = []
    C_mat = []
    
    for t in tqdm(range(test_length - f), desc = 'looping'):
        history = data[:,offset + t-h+1:offset + t+1,:]
        forecast = forecaster(model,history,f) # N x f x 2

        #print(forecast.shape)

        Q_next,M_next = get_next_step(W,b_max,Q_max,B_mat[t],forecast,gamma,alpha)
        Q_mat.append(Q_next)
        M_mat.append(M_next)

        supply_real_offset = data_real[:, t+1, 0]
        demand_real_offset = data_real[:, t+1, 1]
        Q_next_sum = np.sum(Q_next, axis=1)
        
        B_next = B_mat[t][:] + supply_real_offset - demand_real_offset + Q_next_sum + M_next
        B_next_clipped = np.clip(B_next, np.zeros(len(b_max)), b_max)

        c = B_next-B_next_clipped 
        
        C_mat.append(np.where(c< 0,c,0))
        B_mat.append(B_next_clipped)

        # print(B_next_allowed)

    return np.array(Q_mat),np.array(B_mat),np.array(M_mat), np.array(C_mat)

# %% [markdown]
# #### param setup

# %%
# importing data
experiment_type = "small"
data_directory = '../data/experiment_' + experiment_type + '/'
data = np.load(data_directory + 'network_params/data_network.npy')
data = np.transpose(data, (1,2, 0))

B_init = np.zeros(len(data))
f = 7
test_length = 365

G = nx.read_graphml(data_directory + "network_params/graph.graphml")
W = nx.to_numpy_array(G,weight='weight')

b_max = 2000*np.ones(len(data))
Q_max = 100 #100
gamma=0.999
alpha = 10**-3 #1.0
W
# Out:
# array([[  0. ,  35.4, 403. , 403. ],
#        [ 35.4,   0. , 370. , 370. ],
#        [403. , 370. ,   0. ,   1.4],
#        [403. , 370. ,   1.4,   0. ]])

# %%
def data_slice(data, h, f):
    T = h + f
    samples = np.array([data[:,t:t + T,:] for t in range(len(data[0]) - T + 1)])
    return samples[:, :, :h, :], samples[:, : , h:, :]

# %%
def get_plots(Q, B, M, Q_max, b_max, tag = ''):
    total_b_max = np.sum(b_max)
    T, N = M.shape

    # Apply Seaborn styling
    sns.set_theme(style="whitegrid")
    
    # Blood bank stock stack plot
    plt.figure(figsize=(10, 6))
    plt.stackplot(np.arange(T+1), B.T, labels=['Orange County', 'Los Angeles', 'Alta Bates', 'Oakland'])
    # plt.ylim(0, total_b_max)  # Corrected ylim usage
    plt.title('Blood Stock Levels Over Time', fontsize=14)
    plt.xlabel('Time (Days)', fontsize=12)
    plt.ylabel('Blood Stock (Units)', fontsize=12)
    plt.legend(loc='upper right')
    plt.tight_layout()
    plt.savefig("images/" + tag + '_B.png')
    plt.show()

    
    # Blood loan stack plot
    plt.figure(figsize=(10, 6))
    plt.stackplot(np.arange(T), M.T, labels=['Orange County', 'Los Angeles', 'Alta Bates', 'Oakland'], edgecolor = 'None')
    plt.title('Blood Loan', fontsize=14)
    plt.xlabel('Time (Days)', fontsize=12)
    plt.ylabel('Blood Loan (Units)', fontsize=12)
    plt.legend(loc='upper right')
    plt.tight_layout()
    plt.savefig("images/" + tag + '_M.png')
    plt.show()

    # Heatmap of net blood shipping
    fig, ax = plt.subplots(figsize=(12, 8))
    shipping_map = np.sum(Q, axis=1).T
    sns.heatmap(
        data=shipping_map,
        vmin=-Q_max,
        vmax=Q_max,
        cmap="coolwarm",
        cbar_kws={'label': 'Net Blood Flow (Units)'},
        yticklabels=['Orange County', 'Los Angeles', 'Alta Bates', 'Oakland']
    )
    plt.title('Net Blood Shipping', fontsize=16)
    plt.xlabel('Time (Days)', fontsize=12)
    plt.ylabel('Locations', fontsize=12)
    plt.tight_layout()
    plt.savefig("images/" + tag + '_Q.png')
    plt.show()

# %% [markdown]
# #### perfect knowledge

# %%
def perfect_knowledge(W, b_max, Q_max, B_init, S, D, alpha = 1.0, shipment = True):

    N, T = S.shape
    
    B = cp.Variable([N,T+1])
    Q = cp.Variable([N,N,T])
    M = cp.Variable([N,T])
    
    obj_func = cp.sum([cp.norm(m_k,1) for m_k in M]) + alpha*cp.sum([cp.norm(cp.multiply(W,Q[:,:,t]),2) for t in range(T)])
    obj = cp.Minimize(obj_func)
    
    constr =  []
    
    # IC
    constr += [B[:,0] == B_init]
    
    # max storage
    for t in range(T+1):
        constr +=[B[:,t]<=b_max]
        
    # dynamics    
    for t in range(T):
        for k in range(N):
            constr += [B[k,t+1] == B[k,t] + S[k,t] - D[k,t] + cp.sum(Q[k,:,t])+ M[k,t]]
    
    # storage constraints
    for t in range(T+1):
        constr +=[0<= B[:,t]]
    
    
    ##shipments
    for k in range(N):
        for l in range(N):
            constr +=[Q[k,l] == -Q[l,k]]
    
    for k in range(N):
        for t in range(T):
            constr += [cp.sum(Q[:,k,t]) <= B[k,t]]

    if not shipment:
        constr += [Q == 0]
    
    constr += [cp.norm(Q,'inf') <= Q_max]
    prob = cp.Problem(obj,constr)
    prob.solve()
    
    return Q.value.T, B.value.T, M.value.T, prob.value.T

# %%
B_init = np.zeros(len(data))

G = nx.read_graphml(data_directory + "network_params/graph.graphml")
W = nx.to_numpy_array(G,weight='weight')

b_max = 2000*np.ones(len(data))
Q_max = 100 #100
alpha = 10**-3 #1.0
S = data[:,-365:, 0]
D = data[:,-365:, 1]

# %%
Q_perf, B_perf, M_perf, obj_val = perfect_knowledge(W, b_max, Q_max, B_init, S, D, alpha = alpha)
get_plots(Q_perf, B_perf, M_perf, Q_max, b_max, tag = 'perf')

# %%
Q_perf_no_ship, B_perf_no_ship, M_perf_no_ship, obj_val = perfect_knowledge(W, b_max, Q_max, B_init, S, D, alpha = alpha, shipment = False)
get_plots(Q_perf_no_ship, B_perf_no_ship, M_perf_no_ship, 0, b_max, tag = 'perf_noship')

# %% [markdown]
# #### baseline: ZOH

# %%
def get_ZOH_forecast(model, history, f):
    forecast = np.tile(history[:, -1:, :], (1, f, 1))
    return forecast

# %%
h = 1
data_train = data[:,:-3*test_length,:]
hist_train, future_train = data_slice(data_train, h = h, f = f)
ZOH_model = None

# %%
Q_ZOH, B_ZOH, M_ZOH, C_ZOH = forecast_loop(
    data=data,
    B_init = B_init,
    test_length=test_length,
    W=W,
    b_max=b_max,
    Q_max=Q_max,
    forecaster=get_ZOH_forecast,
    model=ZOH_model,
    f=f,
    h=h,
    gamma=gamma,
    alpha=alpha
)
# Out:
# looping: 100%|████████████████████████████████| 358/358 [01:59<00:00,  2.99it/s]

# %%
get_plots(Q_ZOH, B_ZOH, M_ZOH, Q_max, b_max, tag = 'ZOH')

# %% [markdown]
# #### baseline: histmean

# %%
def get_histmean_forecast(model, history, f):
    hist_diff = np.diff(history, axis = 1)
    mean_diff = np.mean(hist_diff, axis = 1, keepdims = True)
    tile = history[:,-1]
    slices = np.tile(np.arange(1,f+1), (len(history),1))
    slices = np.array([slices, slices]).transpose(1,2,0)
    add = np.tile(mean_diff,(1,f,1))*slices
    forecast =  np.repeat(tile[:, np.newaxis, :],f, axis=1) + add
    return forecast

# %%
h = 12
histmean_model = None

# %%
Q_HM, B_HM, M_HM, C_HM = forecast_loop(
    data=data,
    B_init = B_init,
    test_length=test_length,
    W=W,
    b_max=b_max,
    Q_max=Q_max,
    forecaster=get_histmean_forecast,
    model=histmean_model,
    f=f,
    h=h,
    gamma=gamma,
    alpha=alpha
)
# Out:
# looping: 100%|████████████████████████████████| 358/358 [01:50<00:00,  3.24it/s]

# %%
get_plots(Q_HM, B_HM, M_HM, Q_max, b_max,tag='HM')

# %% [markdown]
# #### AR

# %%
def fit_AR_forecaster(hist_samples, future_samples):
  
    m, N, h, _ = hist_samples.shape
    _, _, f, _ = future_samples.shape
    
    hist_sample_matrix = hist_samples.reshape(m, N * h * 2)
    future_sample_matrix = future_samples.reshape(m, N * f * 2)
    
    model = LinearRegression()
    model.fit(hist_sample_matrix, future_sample_matrix)
    return model

def get_AR_forecast(AR_model, history,aux=1):
    N, h, _ = history.shape
    f = len(AR_model.intercept_)// (N * 2)
    history = np.array([history.reshape(N * h *2)])
    forecast = AR_model.predict(history)
    return forecast.reshape(N,f,2)

# %%
h = 11
data_train = data[:,:-3*test_length,:]
hist_train, future_train = data_slice(data_train, h = h, f = f)
AR_model = fit_AR_forecaster(hist_train, future_train)

# %%
Q_AR, B_AR, M_AR, C_AR = forecast_loop(
    data=data,
    B_init = B_init,
    test_length=test_length,
    W=W,
    b_max=b_max,
    Q_max=Q_max,
    forecaster=get_AR_forecast,
    model=AR_model,
    f=f,
    h=h,
    gamma=gamma,
    alpha=alpha
)
# Out:
# looping: 100%|████████████████████████████████| 358/358 [01:50<00:00,  3.24it/s]

# %%
get_plots(Q_AR, B_AR, M_AR, Q_max, b_max, tag = 'AR')

# %% [markdown]
# #### grad boost

# %%
def fit_gbst_forecaster(hist_samples, future_samples, params):
    m, N, h, _ = hist_samples.shape
    _, _, f, _ = future_samples.shape
    
    hist_sample_matrix = hist_samples.reshape(m  , N *  h * 2)
    future_sample_matrix = future_samples.reshape(m , N * f * 2)
    gbst = xgb.XGBRegressor(max_depth = params['max_depth'], min_child_weight = params['min_child_weight'],
                            learning_rate = params['learning_rate'])

    gbst.fit(hist_sample_matrix, future_sample_matrix)
    return gbst

def get_gbst_forecast(gbst_model, history,aux):
    N, h, _ = history.shape
    history = np.array([history.reshape(N * h * 2)])

    forecast = gbst_model.predict(history)

    f = forecast.shape[1] // (N*2)
    return forecast.reshape(N,f,2)

# %%
h = 13
data_train = data[:,:-3*test_length,:]
hist_train, future_train = data_slice(data_train, h = h, f = f)
params = {'max_depth': 1, 'learning_rate': 0.5, 'min_child_weight': 0}

# %%
gbst_model = fit_gbst_forecaster(hist_train, future_train, params)

# %%
Q_gbst,B_gbst,M_gbst, C_gbst = forecast_loop(
    data=data,
    B_init = B_init,
    test_length=test_length,
    W=W,
    b_max=b_max,
    Q_max=Q_max,
    forecaster=get_gbst_forecast,
    model=gbst_model,
    f=f,
    h=h,
    gamma=gamma,
    alpha=alpha
)
# Out:
# looping: 100%|████████████████████████████████| 358/358 [02:06<00:00,  2.82it/s]

# %%
get_plots(Q_gbst, B_gbst, M_gbst, Q_max, b_max, tag = 'gbst')

# %% [markdown]
# ### bVAr

# %%
def _forecast(data,alpha,beta,noise,f):
    len_data = len(data)
    h = len(beta)
    data_forecast = np.zeros((data.shape[0]+f,data.shape[1]))
    data_forecast[:len_data] = data[:]

    for t in range(f):
        ar = []
        for n in range(data.shape[1]):
            ar_n = np.sum(beta[:,n]*data_forecast[len_data+t-h:len_data+t])
            ar.append(ar_n)
        mu = alpha + np.stack(ar,axis=-1)
        data_forecast[len_data+t] = np.random.normal(mu,noise)
    data_forecast[:-f-1] = np.nan
    return data_forecast

def get_bayesian_forecast(trace,history,sample_size=2000):
    chains, draws = trace.posterior.sizes["chain"],trace.posterior.sizes["draw"]
    sample_indices = np.random.randint(draws*chains,size=sample_size)
    post = trace.posterior.stack(sample=("chain","draw"))
    alpha_draws = post["alpha"].values.T[sample_indices]
    beta_draws = post["beta"].values.T[sample_indices].T
    beta_draws = np.moveaxis(beta_draws,-1,0)
    noise_draws = post["noise"].values.T[sample_indices]

    alpha_avg=np.mean(alpha_draws,axis=0)
    beta_avg=np.mean(beta_draws,axis=0)
    noise_avg=np.mean(noise_draws,axis=0)

    N,h,_ = history.shape
    history_resh = history.transpose(1,0,2).reshape(h,2*N)
    history_resh_diff = np.diff(history_resh,axis=0)

    #print(history_resh_diff.shape)
    #print(alpha_avg.shape)
    #print(beta_avg.shape)
    #print(noise_avg.shape)
    
    forecast_avg = _forecast(history_resh_diff,alpha_avg,beta_avg,noise_avg,f=f)
    forecast_avg = forecast_avg[-f:,:]
    forecast_avg = history_resh[-1,:] + np.cumsum(forecast_avg,axis=1)
    return forecast_avg.reshape(forecast_avg.shape[0],forecast_avg.shape[1]//2,2).transpose(1,0,2)

# %%
bvar_model = az.from_netcdf('trace.nc')
h=3
f=2

# %%
Q_bvar,B_bvar,M_bvar,C_bvar = forecast_loop(
    data=data,
    B_init = B_init,
    test_length=test_length,
    W=W,
    b_max=b_max,
    Q_max=Q_max,
    forecaster=get_bayesian_forecast,
    model=bvar_model,
    f=f,
    h=h+1,
    gamma=gamma,
    alpha=alpha
)
# Out:
# looping: 100%|████████████████████████████████| 363/363 [00:36<00:00,  9.83it/s]

# %%
get_plots(Q_bvar, B_bvar, M_bvar, Q_max, b_max, tag = 'bvar')

# %% [markdown]
# #### errors

# %%
def get_total_error(M,W,Q,C,alpha,beta):
    f = len(M)
    error = 0
    
    for t in range(f):
        error += np.linalg.norm(M[t,:],1) + alpha*np.linalg.norm(np.multiply(W,Q[t,:,:]),2) + beta*np.linalg.norm(C[t,:],1)
        
    return error

# %%
get_total_error(M_AR,W,Q_AR,C_AR, alpha, beta = 1)
# Out:
# 1300.6737061044364

# %%
get_total_error(M_gbst,W,Q_gbst,C_gbst, alpha, beta = 1)
# Out:
# 1372.814822043403

# %%
get_total_error(M_HM,W,Q_HM,C_HM, alpha, beta = 1)
# Out:
# 1333.324359024629

# %%
get_total_error(M_bvar,W,Q_bvar,C_bvar, alpha, beta = 1)
# Out:
# 1433.226589461763

# %%
get_total_error(M_ZOH,W,Q_ZOH,C_ZOH, alpha, beta = 1)
# Out:
# 1345.2757107032714

# %%
get_total_error(M_perf, W, Q_perf, np.zeros(M_perf.shape), alpha, beta=1)
get_total_error(M_perf_no_ship, W, Q_perf_no_ship, np.zeros(M_perf.shape), alpha, beta=1)
