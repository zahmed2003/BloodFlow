# %% [markdown]
# # Bayesian Forecaster

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pymc as pm
import pytensor.tensor as pt
import pandas as pd
import arviz as az
import matplotlib.pyplot as plt

# %% [markdown]
# #### data setup

# %%
# importing data
experiment_type = "small"
data_directory = '../data/experiment_' + experiment_type + '/'
data = np.load(data_directory + 'network_params/data_network.npy')
data = np.transpose(data, (2,1, 0))

#reshaping and trimming to exclude the last year
data = data.reshape(len(data),2*len(data[0]))
data_future = data[-365:,:]
data = data[:-365,:]
diffs = np.diff(data, axis=0)
T,D = diffs.shape

# creating the dataframe
hospital_list = np.genfromtxt(data_directory + 'network_params/hospitals.txt', dtype=str, delimiter='\n', comments=None)
df_cols = np.array([[h + ' supply',h + ' demand'] for h in hospital_list]).reshape(D)
df = pd.DataFrame(diffs, columns=df_cols)

df
# Out:
#       Orange County supply  Orange County demand  Los Angeles supply  \
# 0                -0.822526              4.916822           -0.651468
# 1                -5.102420             -2.577938           -5.759107
# 2                -6.269205            -12.057078           -7.188447
# 3                 0.079720              2.358417            0.267309
# 4                -1.913910             -2.842920           -2.149450
# ...                    ...                   ...                 ...
# 2430             -0.899845            -14.163699            0.587018
# 2431              1.472640              0.135780            3.274986
# 2432             -2.883060             -3.278674           -2.002158
# 2433              0.087679            -12.853251            1.380144
# 2434              1.770980             -1.632166            3.235313
#
#       Los Angeles demand  Alta Bates supply  Alta Bates demand  \
# 0               5.990946          -0.181573           1.195645
# 1              -3.141480          -1.605124          -0.864180
# 2             -14.690660          -2.003511          -3.462579
# 3               2.874134           0.074500           0.414624
# 4              -3.464546          -0.599088          -1.026598
# ...                  ...                ...                ...
# 2430          -17.257458           0.163598          -3.213076
# 2431            0.165333           0.912769           0.628585
# 2432           -3.994878          -0.558006          -0.334074
# 2433          -15.660753           0.384651          -2.969376
# 2434           -1.988649           0.901725           0.029325
#
#       Oakland supply  Oakland demand
# 0          -0.153877        0.551387
# 1          -0.954659       -0.499657
# 2          -1.172944       -1.826633
# 3           0.014919        0.172501
# 4          -0.358112       -0.558890
# ...              ...             ...
# 2430        0.092840       -1.650026
# 2431        0.518024        0.322800
# 2432       -0.316684       -0.171561
# 2433        0.218307       -1.524874
# 2434        0.511745        0.015059
#
# [2435 rows x 8 columns]

# %% [markdown]
# #### constructing the BVAR model

# %%
def ar_update(beta, n, h, df):
    update = [
        pm.math.sum([
            pm.math.sum(beta[i,j]*df.values[h-(j+1):-(j+1)], axis=-1)
            for j in range(h)
        ], axis=0)
    for i in range(n)]
    return pm.math.stack(update, axis=-1)

def bvar_model(h,df,priors,draws=2000,tune=1000,chains=4,cores=4,max_treedepth=10):
    coords = {
        "lags": np.arange(h)+1,
        "vars": df.columns.tolist(),
        "eqs": df.columns.tolist(),
        "time": [t for t in df.index[h:]]
    }

    with pm.Model(coords=coords) as model:
        beta = pm.Normal(
            "beta",
            mu=priors["beta"]["mu"],
            sigma=priors["beta"]["sigma"],
            dims=("eqs","lags","vars")
        )
        alpha = pm.Normal(
            "alpha",
            mu=priors["alpha"]["mu"],
            sigma=priors["alpha"]["sigma"],
            dims=("eqs",)
        )
        data_obs = pm.Data(
            "data_obs",
            df.values[h:], 
            dims=("time","eqs"),
        )

        n = df.shape[1]
        betaX = ar_update(beta,n,h,df)
        betaX = pm.Deterministic(
            "betaX",
            betaX,
            dims=("time","eqs")
        )
        mu = alpha + betaX
        sigma = pm.HalfNormal(
            "noise",
            sigma=priors["noise"]["sigma"],
            dims=["vars"]
        )
        obs = pm.Normal(
            "obs",
            mu=mu,
            sigma=sigma,
            observed=data_obs,
            dims=["time","eqs"]
            )
        trace = pm.sample(
            draws=2000,
            tune=1000,
            chains=4,
            cores=4,
            random_seed=42,
            target_accept=0.95,
        )
    return model,trace

# %%
h = 3

priors = {
    "beta": {"mu": 0.0, "sigma": 10.0},
    "alpha": {"mu": 0.0, "sigma": 10.0},
    "noise": {"sigma": 10.0}
}

model, trace = bvar_model(h, df, priors)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, alpha, noise]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 9
#       1 h = 3
#       3 priors = {
#       4     "beta": {"mu": 0.0, "sigma": 10.0},
#       5     "alpha": {"mu": 0.0, "sigma": 10.0},
#       6     "noise": {"sigma": 10.0}
#       7 }
# ----> 9 model, trace = bvar_model(h, df, priors)
#
# Cell In[33], line 57, in bvar_model(h, df, priors, draws, tune, chains, cores, max_treedepth)
#      45     sigma = pm.HalfNormal(
#      46         "noise",
#      47         sigma=priors["noise"]["sigma"],
#      48         dims=["vars"]
#      49     )
#      50     obs = pm.Normal(
#      51         "obs",
#      52         mu=mu,
#    (...)
#      55         dims=["time","eqs"]
#      56         )
# ---> 57     trace = pm.sample(
#      58         draws=2000,
#      59         tune=1000,
#      60         chains=4,
#      61         cores=4,
#      62         random_seed=42,
#      63         target_accept=0.95,
#      64     )
#      65 return model,trace
#
# File /usr/local/Caskroom/miniconda/base/envs/bloodflow/lib/python3.12/site-packages/pymc/sampling/mcmc.py:927, in sample(draws, tune, chains, cores, random_seed, progressbar, progressbar_theme, step, var_names, nuts_sampler, initvals, init, jitter_max_retries, n_init, trace, discard_tuned_samples, compute_convergence_checks, keep_warning_stat, return_inferencedata, idata_kwargs, nuts_sampler_kwargs, callback, mp_ctx, blas_cores, model, compile_kwargs, **kwargs)
#     923 t_sampling = time.time() - t_start
#     925 # Packaging, validating and returning the result was extracted
#     926 # into a function to make it easier to test and refactor.
# --> 927 return _sample_return(
#     928     run=run,
#     929     traces=traces,
#     930     tune=tune,
#     931     t_sampling=t_sampling,
#     932     discard_tuned_samples=discard_tuned_samples,
#     933     compute_convergence_checks=compute_convergence_checks,
#     934     return_inferencedata=return_inferencedata,
#     935     keep_warning_stat=keep_warning_stat,
#     936     idata_kwargs=idata_kwargs or {},
#     937     model=model,
#     938 )
#
# File /usr/local/Caskroom/miniconda/base/envs/bloodflow/lib/python3.12/site-packages/pymc/sampling/mcmc.py:960, in _sample_return(run, traces, tune, t_sampling, discard_tuned_samples, compute_convergence_checks, return_inferencedata, keep_warning_stat, idata_kwargs, model)
#     958 # Pick and slice chains to keep the maximum number of samples
#     959 if discard_tuned_samples:
# --> 960     traces, length = _choose_chains(traces, tune)
#     961 else:
#     962     traces, length = _choose_chains(traces, 0)
#
# File /usr/local/Caskroom/miniconda/base/envs/bloodflow/lib/python3.12/site-packages/pymc/backends/base.py:624, in _choose_chains(traces, tune)
#     622 lengths = [max(0, len(trace) - tune) for trace in traces]
#     623 if not sum(lengths):
# --> 624     raise ValueError("Not enough samples to build a trace.")
#     626 idxs = np.argsort(lengths)
#     627 l_sort = np.array(lengths)[idxs]
#
# ValueError: Not enough samples to build a trace.

# %% [markdown]
# #### looking at the model

# %%
az.summary(trace, var_names=["alpha", "beta","noise"])
# Out:
# arviz - WARNING - Shape validation failed: input_shape: (1, 116), minimum_shape: (chains=2, draws=4)
#                               mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# alpha[Orange County supply] -0.076  0.053  -0.170    0.033      0.017
# alpha[Orange County demand] -0.052  0.102  -0.233    0.114      0.084
# alpha[Los Angeles supply]    0.090  0.050  -0.000    0.185      0.023
# alpha[Los Angeles demand]    0.006  0.128  -0.192    0.142      0.106
# alpha[Alta Bates supply]     0.019  0.024  -0.013    0.068      0.014
# ...                            ...    ...     ...      ...        ...
# noise[Los Angeles demand]    6.354  0.033   6.300    6.407      0.028
# noise[Alta Bates supply]     1.653  0.014   1.624    1.678      0.009
# noise[Alta Bates demand]     1.857  0.012   1.837    1.878      0.010
# noise[Oakland supply]        0.783  0.005   0.775    0.791      0.002
# noise[Oakland demand]        0.950  0.008   0.936    0.964      0.006
#
#                              mcse_sd  ess_bulk  ess_tail  r_hat
# alpha[Orange County supply]    0.012      10.0      20.0    NaN
# alpha[Orange County demand]    0.078       1.0      20.0    NaN
# alpha[Los Angeles supply]      0.018       5.0      20.0    NaN
# alpha[Los Angeles demand]      0.100       2.0      20.0    NaN
# alpha[Alta Bates supply]       0.011       3.0      12.0    NaN
# ...                              ...       ...       ...    ...
# noise[Los Angeles demand]      0.027       2.0      21.0    NaN
# noise[Alta Bates supply]       0.007       3.0      16.0    NaN
# noise[Alta Bates demand]       0.010       1.0      22.0    NaN
# noise[Oakland supply]          0.001       7.0      20.0    NaN
# noise[Oakland demand]          0.005       2.0      43.0    NaN
#
# [208 rows x 9 columns]

# %%
#fig, ax = plt.subplots(figsize=(20, 100))
az.plot_forest(trace, var_names=["alpha"], combined=True, textsize=10)
plt.axvline(0, color="k", ls="--")
plt.title("Parameter Distribution");

# %%
az.plot_posterior(trace, var_names=["noise"]);

# %% [markdown]
# #### forecasting

# %%
def get_posterior_sample(trace):
    beta_samples = trace.posterior["beta"].values  # Shape: (chains, samples, eqs, lags,variables)
    alpha_samples = trace.posterior["alpha"].values  # Shape: (chains,samples,eqs)
    noise_samples = trace.posterior["noise"].values  # Shape: (chains,samples,eqs)

    rand_chain = np.random.randint(0,len(beta_samples))
    rand_sample = np.random.randint(0,len(beta_samples[0]))
    
    return alpha_samples[rand_chain,rand_sample],beta_samples[rand_chain,rand_sample],noise_samples[rand_chain,rand_sample]

def get_prediction(f,alpha_sample,beta_sample,noise_sample,history):
# Out:
#   Cell In[32], line 12
#
#     ^
# SyntaxError: incomplete input

# %%
alpha_sample,beta_sample,noise_sample = get_posterior_sample(trace)
# Out:
# (4,)
