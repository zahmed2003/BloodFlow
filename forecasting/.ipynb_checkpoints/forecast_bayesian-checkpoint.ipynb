# %% [markdown]
# # Bayesian Forecaster

# %% [markdown]
# #### Imports

# %%
import numpy as np
import pymc as pm
import pytensor.tensor as pt
import pandas as pd
import arviz as az
import matplotlib.pyplot as plt
import netCDF4
import xarray as xr
import pickle

# %% [markdown]
# #### data setup

# %%
# importing data
experiment_type = "verysmall"
data_directory = '../data/experiment_' + experiment_type + '/'
data = np.load(data_directory + 'network_params/data_network.npy')
data = np.transpose(data, (2,1, 0))

#reshaping and trimming to exclude the last year
data = data.reshape(len(data),2*len(data[0]))
data_future = data[-365:,:]
data = data[:-365,:]
diffs = np.diff(data, axis=0)
T,D = diffs.shape

# creating the dataframe
hospital_list = np.loadtxt(data_directory + 'network_params/hospitals.txt', dtype=str, delimiter='\n')
df_cols = np.array([[h + ' supply',h + ' demand'] for h in hospital_list]).reshape(D)
df = pd.DataFrame(diffs, columns=df_cols)

df
# Out:
#       Orange County supply  Orange County demand  Oakland supply  \
# 0                 0.631582             -0.877368        0.097019
# 1                 1.741602              3.733479        0.267541
# 2                 4.569952              5.611188        0.702018
# 3                 3.248084              1.434755        0.498933
# 4                 0.920804              0.176321        0.141446
# ...                    ...                   ...             ...
# 2430             -6.829226             -1.746880       -1.049062
# 2431              0.061868             -0.537839        0.009503
# 2432             -1.156395             -4.148470       -0.177636
# 2433             -0.541819             -4.171408       -0.083234
# 2434             -0.100898             -4.588782       -0.015500
#
#       Oakland demand
# 0          -0.122130
# 1           0.519669
# 2           0.781017
# 3           0.199722
# 4           0.024533
# ...              ...
# 2430       -0.243154
# 2431       -0.074859
# 2432       -0.577435
# 2433       -0.580625
# 2434       -0.638717
#
# [2435 rows x 4 columns]

# %% [markdown]
# #### constructing the BVAR model

# %%
def ar_update(beta,n,h,df):
    df_values = df.values[h:]
    update = [
        pm.math.sum([
            pm.math.sum(beta[i,j] * df.values[h-(j+1):-(j+1)],axis=-1)
            for j in range(h)
        ],axis=0)
    for i in range(n)]
    return pm.math.stack(update, axis=-1)

def bvar_model(h,df,priors,draws=2000,tune=1000,chains=4,cores=4,max_treedepth=10):
    coords = {
        "lags": np.arange(h)+1,
        "vars": df.columns.tolist(),
        "eqs": df.columns.tolist(),
        "time": [t for t in df.index[h:]]
    }

    with pm.Model(coords=coords) as model:
        beta = pm.Normal(
            "beta",
            mu=priors["beta"]["mu"],
            sigma=priors["beta"]["sigma"],
            dims=("eqs","lags","vars")
        )
        alpha = pm.Normal(
            "alpha",
            mu=priors["alpha"]["mu"],
            sigma=priors["alpha"]["sigma"],
            dims=("eqs",)
        )
        data_obs = pm.Data(
            "data_obs",
            df.values[h:], 
            dims=("time","eqs"),
            mutable=True
        )

        n = df.shape[1]
        betaX = ar_update(beta,n,h,df)
        betaX = pm.Deterministic(
            "betaX",
            betaX,
            dims=("time",)
        )
        mu = alpha + betaX
        sigma = pm.HalfNormal(
            "noise",
            sigma=priors["noise"]["sigma"],
            dims=["vars"]
        )
        obs = pm.Normal(
            "obs",
            mu=mu,
            sigma=sigma,
            observed=data_obs,
            dims=["time","eqs"]
            )
        trace = pm.sample(
            draws=2000,
            tune=1000,
            chains=4,
            cores=4,
            random_seed=42,
            target_accept=0.95,
            nuts_sampler_kwargs={"max_treedepth": 10},
        )
    return model,trace

# %%
h = 3

priors = {
    "beta": {"mu": 0.0, "sigma": 10.0},
    "alpha": {"mu": 0.0, "sigma": 10.0},
    "noise": {"sigma": 10.0}
}

model, trace = bvar_model(h, df, priors)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [beta, alpha, noise]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='12000' class='' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [12000/12000 42:29&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 2_000 draw iterations (4_000 + 8_000 draws total) took 2582 seconds.
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Chain 0 reached the maximum tree depth. Increase `max_treedepth`, increase `target_accept` or reparameterize.
# Chain 1 reached the maximum tree depth. Increase `max_treedepth`, increase `target_accept` or reparameterize.
# Chain 2 reached the maximum tree depth. Increase `max_treedepth`, increase `target_accept` or reparameterize.
# Chain 3 reached the maximum tree depth. Increase `max_treedepth`, increase `target_accept` or reparameterize.

# %% [markdown]
# #### looking at the model

# %%
az.summary(trace, var_names=["alpha", "beta","noise"])
# Out:
#                                                      mean      sd  hdi_3%  \
# alpha[Orange County supply]                         0.049   0.068  -0.078
# alpha[Orange County demand]                         0.020   0.075  -0.109
# alpha[Oakland supply]                               0.007   0.011  -0.013
# alpha[Oakland demand]                               0.003   0.011  -0.017
# beta[Orange County supply, 1, Orange County sup...  0.073   1.601  -3.118
# beta[Orange County supply, 1, Orange County dem...  0.438   1.389  -2.262
# beta[Orange County supply, 1, Oakland supply]       0.203  10.420 -18.772
# beta[Orange County supply, 1, Oakland demand]      -3.349   9.975 -19.462
# beta[Orange County supply, 2, Orange County sup... -0.046   1.360  -2.542
# beta[Orange County supply, 2, Orange County dem... -0.212   1.361  -2.723
# beta[Orange County supply, 2, Oakland supply]       1.093   8.849 -16.963
# beta[Orange County supply, 2, Oakland demand]       1.574   9.780 -17.028
# beta[Orange County supply, 3, Orange County sup...  0.535   1.469  -2.025
# beta[Orange County supply, 3, Orange County dem... -0.104   1.357  -2.666
# beta[Orange County supply, 3, Oakland supply]      -2.786   9.567 -20.795
# beta[Orange County supply, 3, Oakland demand]       0.667   9.749 -18.644
# beta[Orange County demand, 1, Orange County sup...  0.022   1.430  -3.169
# beta[Orange County demand, 1, Orange County dem... -0.003   1.499  -2.809
# beta[Orange County demand, 1, Oakland supply]       0.080   9.307 -15.151
# beta[Orange County demand, 1, Oakland demand]       0.138  10.767 -18.698
# beta[Orange County demand, 2, Orange County sup...  0.016   1.564  -2.827
# beta[Orange County demand, 2, Orange County dem... -0.068   1.346  -2.768
# beta[Orange County demand, 2, Oakland supply]      -0.227  10.182 -20.667
# beta[Orange County demand, 2, Oakland demand]       0.781   9.670 -16.984
# beta[Orange County demand, 3, Orange County sup...  0.011   1.491  -2.391
# beta[Orange County demand, 3, Orange County dem...  0.074   1.264  -2.230
# beta[Orange County demand, 3, Oakland supply]      -0.161   9.703 -18.829
# beta[Orange County demand, 3, Oakland demand]      -0.307   9.079 -19.787
# beta[Oakland supply, 1, Orange County supply]      -0.056   1.471  -2.850
# beta[Oakland supply, 1, Orange County demand]       0.117   1.383  -2.355
# beta[Oakland supply, 1, Oakland supply]             0.466   9.573 -17.189
# beta[Oakland supply, 1, Oakland demand]            -0.870   9.934 -20.139
# beta[Oakland supply, 2, Orange County supply]       0.149   1.417  -2.679
# beta[Oakland supply, 2, Orange County demand]      -0.165   1.277  -2.488
# beta[Oakland supply, 2, Oakland supply]            -0.848   9.228 -17.578
# beta[Oakland supply, 2, Oakland demand]             1.191   9.175 -17.111
# beta[Oakland supply, 3, Orange County supply]       0.221   1.491  -2.553
# beta[Oakland supply, 3, Orange County demand]       0.187   1.346  -2.251
# beta[Oakland supply, 3, Oakland supply]            -1.329   9.704 -20.344
# beta[Oakland supply, 3, Oakland demand]            -1.358   9.671 -21.579
# beta[Oakland demand, 1, Orange County supply]       0.276   1.347  -2.396
# beta[Oakland demand, 1, Orange County demand]      -0.456   1.427  -3.206
# beta[Oakland demand, 1, Oakland supply]            -1.763   8.771 -18.195
# beta[Oakland demand, 1, Oakland demand]             3.295  10.255 -16.156
# beta[Oakland demand, 2, Orange County supply]      -0.089   1.464  -2.923
# beta[Oakland demand, 2, Orange County demand]       0.157   1.393  -2.546
# beta[Oakland demand, 2, Oakland supply]             0.564   9.528 -16.944
# beta[Oakland demand, 2, Oakland demand]            -1.086  10.008 -19.110
# beta[Oakland demand, 3, Orange County supply]      -0.338   1.529  -3.508
# beta[Oakland demand, 3, Orange County demand]      -0.022   1.408  -2.802
# beta[Oakland demand, 3, Oakland supply]             2.184   9.952 -15.944
# beta[Oakland demand, 3, Oakland demand]             0.186  10.118 -18.435
# noise[Orange County supply]                         3.331   0.047   3.247
# noise[Orange County demand]                         3.766   0.054   3.661
# noise[Oakland supply]                               0.512   0.007   0.498
# noise[Oakland demand]                               0.523   0.008   0.509
#
#                                                     hdi_97%  mcse_mean  \
# alpha[Orange County supply]                           0.178      0.004
# alpha[Orange County demand]                           0.166      0.004
# alpha[Oakland supply]                                 0.027      0.001
# alpha[Oakland demand]                                 0.022      0.001
# beta[Orange County supply, 1, Orange County sup...    3.000      0.144
# beta[Orange County supply, 1, Orange County dem...    2.684      0.148
# beta[Orange County supply, 1, Oakland supply]        21.031      0.940
# beta[Orange County supply, 1, Oakland demand]        16.037      1.061
# beta[Orange County supply, 2, Orange County sup...    2.757      0.151
# beta[Orange County supply, 2, Orange County dem...    2.402      0.198
# beta[Orange County supply, 2, Oakland supply]        17.526      0.984
# beta[Orange County supply, 2, Oakland demand]        19.774      1.420
# beta[Orange County supply, 3, Orange County sup...    3.307      0.353
# beta[Orange County supply, 3, Orange County dem...    2.519      0.087
# beta[Orange County supply, 3, Oakland supply]        13.972      2.296
# beta[Orange County supply, 3, Oakland demand]        18.591      0.627
# beta[Orange County demand, 1, Orange County sup...    2.357      0.149
# beta[Orange County demand, 1, Orange County dem...    2.652      0.166
# beta[Orange County demand, 1, Oakland supply]        20.785      0.968
# beta[Orange County demand, 1, Oakland demand]        20.500      1.193
# beta[Orange County demand, 2, Orange County sup...    3.141      0.222
# beta[Orange County demand, 2, Orange County dem...    2.405      0.121
# beta[Orange County demand, 2, Oakland supply]        18.140      1.447
# beta[Orange County demand, 2, Oakland demand]        20.165      0.866
# beta[Orange County demand, 3, Orange County sup...    2.862      0.254
# beta[Orange County demand, 3, Orange County dem...    2.662      0.227
# beta[Orange County demand, 3, Oakland supply]        15.343      1.653
# beta[Orange County demand, 3, Oakland demand]        15.323      1.630
# beta[Oakland supply, 1, Orange County supply]         2.654      0.233
# beta[Oakland supply, 1, Orange County demand]         2.799      0.104
# beta[Oakland supply, 1, Oakland supply]              18.641      1.517
# beta[Oakland supply, 1, Oakland demand]              16.885      0.744
# beta[Oakland supply, 2, Orange County supply]         2.543      0.153
# beta[Oakland supply, 2, Orange County demand]         2.382      0.127
# beta[Oakland supply, 2, Oakland supply]              16.390      0.997
# beta[Oakland supply, 2, Oakland demand]              17.863      0.911
# beta[Oakland supply, 3, Orange County supply]         3.140      0.132
# beta[Oakland supply, 3, Orange County demand]         3.001      0.132
# beta[Oakland supply, 3, Oakland supply]              16.723      0.856
# beta[Oakland supply, 3, Oakland demand]              16.135      0.951
# beta[Oakland demand, 1, Orange County supply]         2.799      0.162
# beta[Oakland demand, 1, Orange County demand]         2.252      0.194
# beta[Oakland demand, 1, Oakland supply]              15.638      1.057
# beta[Oakland demand, 1, Oakland demand]              23.041      1.397
# beta[Oakland demand, 2, Orange County supply]         2.594      0.139
# beta[Oakland demand, 2, Orange County demand]         2.664      0.128
# beta[Oakland demand, 2, Oakland supply]              18.958      0.906
# beta[Oakland demand, 2, Oakland demand]              18.316      0.919
# beta[Oakland demand, 3, Orange County supply]         2.448      0.255
# beta[Oakland demand, 3, Orange County demand]         2.525      0.136
# beta[Oakland demand, 3, Oakland supply]              22.815      1.661
# beta[Oakland demand, 3, Oakland demand]              19.829      0.977
# noise[Orange County supply]                           3.421      0.002
# noise[Orange County demand]                           3.865      0.003
# noise[Oakland supply]                                 0.525      0.000
# noise[Oakland demand]                                 0.537      0.000
#
#                                                     mcse_sd  ess_bulk  \
# alpha[Orange County supply]                           0.003     350.0
# alpha[Orange County demand]                           0.003     312.0
# alpha[Oakland supply]                                 0.000     261.0
# alpha[Oakland demand]                                 0.000     339.0
# beta[Orange County supply, 1, Orange County sup...    0.102     127.0
# beta[Orange County supply, 1, Orange County dem...    0.105      90.0
# beta[Orange County supply, 1, Oakland supply]         0.666     127.0
# beta[Orange County supply, 1, Oakland demand]         0.753      90.0
# beta[Orange County supply, 2, Orange County sup...    0.107      79.0
# beta[Orange County supply, 2, Orange County dem...    0.141      48.0
# beta[Orange County supply, 2, Oakland supply]         0.699      79.0
# beta[Orange County supply, 2, Oakland demand]         1.010      48.0
# beta[Orange County supply, 3, Orange County sup...    0.254      18.0
# beta[Orange County supply, 3, Orange County dem...    0.062     242.0
# beta[Orange County supply, 3, Oakland supply]         1.652      18.0
# beta[Orange County supply, 3, Oakland demand]         0.444     242.0
# beta[Orange County demand, 1, Orange County sup...    0.105      93.0
# beta[Orange County demand, 1, Orange County dem...    0.118      83.0
# beta[Orange County demand, 1, Oakland supply]         0.687      93.0
# beta[Orange County demand, 1, Oakland demand]         0.847      83.0
# beta[Orange County demand, 2, Orange County sup...    0.158      51.0
# beta[Orange County demand, 2, Orange County dem...    0.089     127.0
# beta[Orange County demand, 2, Oakland supply]         1.029      51.0
# beta[Orange County demand, 2, Oakland demand]         0.614     127.0
# beta[Orange County demand, 3, Orange County sup...    0.181      41.0
# beta[Orange County demand, 3, Orange County dem...    0.162      34.0
# beta[Orange County demand, 3, Oakland supply]         1.179      41.0
# beta[Orange County demand, 3, Oakland demand]         1.164      34.0
# beta[Oakland supply, 1, Orange County supply]         0.166      42.0
# beta[Oakland supply, 1, Orange County demand]         0.073     180.0
# beta[Oakland supply, 1, Oakland supply]               1.081      42.0
# beta[Oakland supply, 1, Oakland demand]               0.527     180.0
# beta[Oakland supply, 2, Orange County supply]         0.109      87.0
# beta[Oakland supply, 2, Orange County demand]         0.090     100.0
# beta[Oakland supply, 2, Oakland supply]               0.708      87.0
# beta[Oakland supply, 2, Oakland demand]               0.646     100.0
# beta[Oakland supply, 3, Orange County supply]         0.093     135.0
# beta[Oakland supply, 3, Orange County demand]         0.094     115.0
# beta[Oakland supply, 3, Oakland supply]               0.607     135.0
# beta[Oakland supply, 3, Oakland demand]               0.675     115.0
# beta[Oakland demand, 1, Orange County supply]         0.115      68.0
# beta[Oakland demand, 1, Orange County demand]         0.138      55.0
# beta[Oakland demand, 1, Oakland supply]               0.751      68.0
# beta[Oakland demand, 1, Oakland demand]               0.993      55.0
# beta[Oakland demand, 2, Orange County supply]         0.099     112.0
# beta[Oakland demand, 2, Orange County demand]         0.091     119.0
# beta[Oakland demand, 2, Oakland supply]               0.643     112.0
# beta[Oakland demand, 2, Oakland demand]               0.652     119.0
# beta[Oakland demand, 3, Orange County supply]         0.182      36.0
# beta[Oakland demand, 3, Orange County demand]         0.096     107.0
# beta[Oakland demand, 3, Oakland supply]               1.184      36.0
# beta[Oakland demand, 3, Oakland demand]               0.693     107.0
# noise[Orange County supply]                           0.002     369.0
# noise[Orange County demand]                           0.002     316.0
# noise[Oakland supply]                                 0.000     338.0
# noise[Oakland demand]                                 0.000     330.0
#
#                                                     ess_tail  r_hat
# alpha[Orange County supply]                            783.0   1.01
# alpha[Orange County demand]                            737.0   1.01
# alpha[Oakland supply]                                  571.0   1.01
# alpha[Oakland demand]                                  692.0   1.01
# beta[Orange County supply, 1, Orange County sup...     213.0   1.02
# beta[Orange County supply, 1, Orange County dem...     246.0   1.03
# beta[Orange County supply, 1, Oakland supply]          208.0   1.02
# beta[Orange County supply, 1, Oakland demand]          246.0   1.03
# beta[Orange County supply, 2, Orange County sup...     245.0   1.04
# beta[Orange County supply, 2, Orange County dem...     150.0   1.07
# beta[Orange County supply, 2, Oakland supply]          245.0   1.04
# beta[Orange County supply, 2, Oakland demand]          151.0   1.07
# beta[Orange County supply, 3, Orange County sup...      87.0   1.16
# beta[Orange County supply, 3, Orange County dem...     519.0   1.01
# beta[Orange County supply, 3, Oakland supply]           88.0   1.16
# beta[Orange County supply, 3, Oakland demand]          509.0   1.01
# beta[Orange County demand, 1, Orange County sup...     365.0   1.05
# beta[Orange County demand, 1, Orange County dem...     180.0   1.03
# beta[Orange County demand, 1, Oakland supply]          372.0   1.05
# beta[Orange County demand, 1, Oakland demand]          181.0   1.03
# beta[Orange County demand, 2, Orange County sup...      52.0   1.06
# beta[Orange County demand, 2, Orange County dem...     196.0   1.04
# beta[Orange County demand, 2, Oakland supply]           50.0   1.06
# beta[Orange County demand, 2, Oakland demand]          194.0   1.04
# beta[Orange County demand, 3, Orange County sup...     139.0   1.08
# beta[Orange County demand, 3, Orange County dem...      37.0   1.11
# beta[Orange County demand, 3, Oakland supply]          139.0   1.08
# beta[Orange County demand, 3, Oakland demand]           39.0   1.11
# beta[Oakland supply, 1, Orange County supply]           48.0   1.08
# beta[Oakland supply, 1, Orange County demand]          443.0   1.01
# beta[Oakland supply, 1, Oakland supply]                 48.0   1.08
# beta[Oakland supply, 1, Oakland demand]                443.0   1.01
# beta[Oakland supply, 2, Orange County supply]          140.0   1.04
# beta[Oakland supply, 2, Orange County demand]          154.0   1.04
# beta[Oakland supply, 2, Oakland supply]                141.0   1.04
# beta[Oakland supply, 2, Oakland demand]                154.0   1.04
# beta[Oakland supply, 3, Orange County supply]          176.0   1.03
# beta[Oakland supply, 3, Orange County demand]          166.0   1.06
# beta[Oakland supply, 3, Oakland supply]                176.0   1.03
# beta[Oakland supply, 3, Oakland demand]                166.0   1.06
# beta[Oakland demand, 1, Orange County supply]          172.0   1.06
# beta[Oakland demand, 1, Orange County demand]          119.0   1.05
# beta[Oakland demand, 1, Oakland supply]                172.0   1.06
# beta[Oakland demand, 1, Oakland demand]                119.0   1.05
# beta[Oakland demand, 2, Orange County supply]          170.0   1.03
# beta[Oakland demand, 2, Orange County demand]          284.0   1.03
# beta[Oakland demand, 2, Oakland supply]                170.0   1.03
# beta[Oakland demand, 2, Oakland demand]                284.0   1.03
# beta[Oakland demand, 3, Orange County supply]          117.0   1.09
# beta[Oakland demand, 3, Orange County demand]          226.0   1.04
# beta[Oakland demand, 3, Oakland supply]                117.0   1.09
# beta[Oakland demand, 3, Oakland demand]                228.0   1.04
# noise[Orange County supply]                            764.0   1.01
# noise[Orange County demand]                            213.0   1.03
# noise[Oakland supply]                                  795.0   1.01
# noise[Oakland demand]                                  700.0   1.01

# %%
#fig, ax = plt.subplots(figsize=(20, 100))
az.plot_forest(trace, var_names=["beta"], combined=True, textsize=10)
plt.axvline(0, color="k", ls="--")
plt.title("Parameter Distribution");

# %%
az.plot_posterior(trace, var_names=["beta"]);

# %% [markdown]
# #### forecasting

# %%
def predict_future(f, trace, h):
    beta_samples = trace.posterior["beta"].values  # Shape: (chains, samples, eqs, lags,variables)
    alpha_samples = trace.posterior["alpha"].values  # Shape: (chains,samples,eqs)
    sigma_samples = trace.posterior["noise"].values  # Shape: (chains,samples,eqs)

    
    return forecasts

# %%
f=3
trace.posterior["beta"].values.shape
#future_predictions = predict_future(f,trace,h)
#future_predictions.shape
# Out:
# (4, 2000, 4, 3, 4)
